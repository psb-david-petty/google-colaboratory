# %% [markdown]
# <a href="https://colab.research.google.com/github/psb-david-petty/google-colaboratory/blob/master/odrisamer_despaigne_club.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unique MLB Players' Names
#
# The [*Odrisamer Despaigne Club*](https://www.baseball-reference.com/players/d/despaod01.shtml) is a club of [Major League Basball](https://www.mlb.com/) players whose first and last names are unique. As of 2021/08 there are 399 members.
#
# - This [Jupyter](http://jupyter.org/) notebook accesses and parses the player database on [https://www.baseball-reference.com/players/](https://www.baseball-reference.com/players/) and creates sets of first and last names.
# - It then looks for players whose first names are unique among first names *and* whose last names are unique among last names (including the 405 players listed by last name only).
# - Finally, it prints the names of the club members &mdash; strict and non-strict.
#
# Some favorites: Creepy Crespi, Pickles Dillhoefer, Pretzels Getzien, Vinegar Bend Mizell, and Twink Twining. Non-strict members Cisco Carlos and Ewing Waddy have unique first and last names, but both their first names are not unique as a last name *and* their last names are not unique as a first name.

# %%
#!/usr/bin/env python3
#
# Look up baseball players and find members of the Odrisamer Despaigne Club.
#
import lxml.etree, lxml.html, os, sys, urllib.request

# !pip install cssselect

def names(alphabet='abcdefghijklmnopqrstuvwxyz', verbose=False):
    """Return dictionary from baseball-reference.com alpahabetical listings."""
    result, parser = dict(), lxml.etree.HTMLParser(encoding='latin1')
    for letter in alphabet.lower():
        url = f"https://www.baseball-reference.com/players/{letter}/index.shtml"
        names = list()
        with urllib.request.urlopen(url) as response:
            doc = lxml.html.parse(response, parser=parser).getroot()
            for elem in doc.cssselect('#div_players_ a'):
                names.append(elem.text)
        if verbose: print(f"{len(names):5d} '{letter.upper()}' {names}")
        result[letter] = names
    return result

# Return l with two separated initial letters formatted into a single name."""
initials = \
    lambda l: [f"{'.'.join([ s.replace('.', '') for s in l[ :2]])}.", ] + l[2: ] \
        if all([ len(s.replace('.', '')) == 1 for s in l[ :2]]) else l

def parse(name):
    """Return first, last parsed from name on spaces. There are a number of 
    special cases:
    - When there are 2 spaces, it often means multiple first names, except a 
      last name w/ one of prefix3 or suffix3.
    - When there are 3 spaces, it often means multiple first names, or a middle
      initial, except a  last name w/ one of prefix4.
    - There is some attempt at normalization (for comparison), including:
    -- 'J C Hartman' -> 'J.C. HARTMAN'
    -- 'Steel Arm Johnny Taylor' -> 'STEEL-ARM-JOHNNY TAYLOR'
    - Formatting on baseball-reference.com is fairly consistent, so there is no 
      attempt to comprehensively cover all cases."""
    prefix3 = ['DE', 'DEL', 'DEN', 'DES', 'LA', 'LO', 'SANTO', 'ST.', 
        'VAN', 'VANDE', 'VANDER', 'VON', 'YELLOW', ]
    suffix3 = ['III', 'JR', 'JR.', 'SR.', ]
    prefix4 = ['DE', 'PONCE', 'VAN', ]
    names = initials([ n.upper() for n in name.split(' ') ])
    if len(names) == 1:
        # Last name only
        return '', name.upper()
    if len(names) == 2:
        # First Last
        return names[0], names[1]
    if len(names) == 3:
        # Three names
        if names[1] in prefix3 or names[2] in suffix3:
            return names[0], ' '.join(names[1: ])
    if len(names) == 4:
        # Four names
        if names[1] in prefix4:
            return names[0], ' '.join(names[1: ])
    # Single Last name
    return '-'.join(names[ :-1]), names[-1]

def odrisamer_despaigne(names, strict=False):
    """Return dictionaries for first and last, and list of unique, names."""
    # Create first and last name dictionaries.
    first_dict, last_dict = dict(), dict()
    for letter in players:
        for name in players[letter]:
            first, last = parse(name)
            first_dict[first] = first_dict.get(first, list()) + [last]
            last_dict[last] = last_dict.get(last, list()) + [first]
    # Calculate unique names where 1 LN for a FN and 1 FN for that LN. 
    unique = [(k, v[0], ) for k, v in first_dict.items() 
        if len(v) == 1 and len(last_dict[v[0]]) == 1 and v[0] not in first_dict['']
            and (not strict or k not in last_dict and v[0] not in first_dict)]
    return first_dict, last_dict, unique

if __name__ == '__main__':
    is_idle, is_pycharm, is_jupyter = (
        'idlelib' in sys.modules,
        int(os.getenv('PYCHARM', 0)),
        '__file__' not in globals()
    )
    if any((is_idle, is_pycharm, is_jupyter,)):
        # Parse MLB players from https://www.baseball-reference.com/players/.
        players = names(verbose=True)
        total = sum([len(players[letter]) for letter in players])
        print(f"{total:5d} {players}")
        # Find members of the Odrisamer Despaigne club and print them.
        first, last, unique = odrisamer_despaigne(names)
        print(f"{len(first):5d}     FIRST: {first}")
        print(f"{len(last):5d}      LAST: {last}")
        print(f"{len(first['']):5d} LAST ONLY: {first['']}")

        print(f"################ Odrisamer Despaigne Club members:")
        print(f"{len(unique):5d} {unique}")
        for fn, ln in unique:
            print(f"* {fn} {ln}"
                f"{'' if fn not in last else f' ({fn} is a last name)'}"
                f"{'' if ln not in first else f' ({ln} is a first name)'}")
        first, last, strict = odrisamer_despaigne(names, strict=True)
        print(f"{len(strict):5d} strict members: {strict}")
        nonstrict = set(unique) - set(strict)
        print(f"{len(nonstrict):5d} non-strict members: {nonstrict}")
# Out:
# Requirement already satisfied: cssselect in /usr/local/lib/python3.7/dist-packages (1.1.0)
#   694 'A' ['David Aardsma', 'Henry Aaron', 'Tommie Aaron', 'Don Aase', 'Andy Abad', 'Fernando Abad', 'John Abadie', 'Ed Abbaticchio', 'Bert Abbey', 'Charlie Abbey', 'Cory Abbott', 'Dan Abbott', 'Fred Abbott', 'Glenn Abbott', 'Jeff Abbott', 'Jim Abbott', 'Kurt Abbott', 'Kyle Abbott', 'Ody Abbott', 'Paul Abbott', 'Al Aber', 'Frank Abercrombie', 'Reggie Abercrombie', 'Bill Abernathie', 'Brent Abernathy', 'James Abernathy', 'Ted Abernathy', 'Ted Abernathy', 'Woody Abernathy', 'Cliff Aberson', 'Harry Ables', 'Shawn Abner', 'Cal Abrams', 'George Abrams', 'Johnny Abrego', 'Albert Abreu', 'Bobby Abreu', 'Bryan Abreu', 'Eufemio Abreu', 'Joe Abreu', 'José Abreu', 'Juan Abreu', 'Tony Abreu', 'Winston Abreu', 'Bill Abstein', 'Jeremy Accardo', 'Domingo Acevedo', 'Jose Acevedo', 'Juan Acevedo', 'Alfredo Aceves', 'A.J. Achter', 'Jim Acker', 'Tom Acker', 'Dustin Ackley', 'Fritz Ackley', 'Cy Acosta', 'Ed Acosta', 'José Acosta', 'Manny Acosta', 'Merito Acosta', 'Mark Acre', 'Ronald Acuna Jr.', 'Jerry Adair', 
LaValliere', 'Doc Lavan', 'Ryan Lavarnway', 'Gary Lavelle', 'Jimmy Lavender', 'Art LaVigne', 'Johnny Lavin', 'Derek Law', 'Ron Law', 'Rudy Law', 'Vance Law', 'Vern Law', 'Garland Lawing', 'Tom Lawless', 'Mike Lawlor', 'Bill Lawrence', 'Bob Lawrence', 'Brian Lawrence', 'Brooks Lawrence', 'Casey Lawrence', 'Jim Lawrence', 'Joe Lawrence', 'Justin Lawrence', 'Sean Lawrence', 'Brett Lawrie', 'Otis Lawry', 'Al Lawson', 'Bob Lawson', 'Phelbert Lawson', 'Roxie Lawson', 'Steve Lawson ...
# ...
# * ABIATAL AVELINO (AVELINO is a first name)
# * SHOOTY BABITT
# * AKIL BADDOO
# * BURKE BADENHOP (BURKE is a last name)
# * CHA-SEUNG BAEK
# * JERSEY BAKLEY
# * ROCCO BALDELLI (ROCCO is a last name)
# * WLADIMIR BALENTIEN
# * PELHAM BALLENGER (PELHAM is a last name)
# * STUDS BANCKER
# * JETT BANDY
# * SALOME BAROJAS (SALOME is a last name)
# * CUNO BARRAGAN
# * KIMERA BARTEE
# * LUIS-ALEXANDER BASABE
# * BURLEY BAYER
# * DARIUS BEA
# * JALEN BEEKS
# * PETIE BEHAN
# * SKINNER BELFIELD (SKINNER is a last name)
# * RENO BERTOIA
# * DELLIN BETANCES
# * RAINEY BIBBS (RAINEY is a last name)
# * RANDOR BIERD
# * RIVINGTON BISLAND
# * RAE BLAEMIRE
# * LINC BLAKELY
# * JABARI BLASH
# * XANDER BOGAERTS
# * SKYE BOLT
# * JUNG BONG
# * BOOF BONSER
# * DOE BOYLAND (DOE is a last name)
# * GIBBY BRACK
# * YHENCY BRAZOBAN
# * FATTY BRIODY
# * JAYCOB BRUGMAN
# * ARLO BRUNSBERG
# * T.R. BRYDEN
# * FRANCISLEY BUENO
# * SIM BULLAS
# * JEROMY BURNITZ
# * SUBBY BYAS
# * PUTSY CABALLERO
# * ARQUIMEDES CAMINERO
# * CARDELL CAMPER
# * JEIMER CANDELARIO
# * CONRAD CARDINAL (CONRAD is a last name)
# * ESMAILIN CARIDAD
# * CISCO CARLOS (CISCO is a last name) (CARLOS is a first name)
# * KEEFE CATO (KEEFE is a last name)
# * GILBERTO CELESTINO
# * YOENIS CÉSPEDES
# * PELAYO CHACÓN
# * ITALO CHELINI
# * JAZZ CHISHOLM
# * JIN-HO CHO
# * SHIN-SOO CHOO (CHOO is a first name)
# * ARCHI CIANFROCCO
# * GALEN CISCO (CISCO is a first name)
# * UKE CLANTON
# * GOWELL CLASET (GOWELL is a last name)
# * HARLOND CLIFT
# * FLEA CLIFTON
# * JD CLOSSER
# * IVANON COFFIE
# * TRACE COQUILLETTE
# * JHAREL COTTON (COTTON is a first name)
# * ENSIGN COTTRELL
# * MARLAN COUGHTRY
# * KALEB COWART
# * CALLIX CRABBE
# * GAVVY CRAVATH
# * CREEPY CRESPI
# * NABIL CRISMATT
# * WALTON CRUISE (WALTON is a last name)
# * PRESS CRUTHERS
# * EGGIE DALLARD
# * LUNIE DANAGE
# * YONATHAN DAZA
# * YURENDELL DE CASTER
# * LIONEL DECUIR
# * GARTON DEL SAVIO (GARTON is a last name)
# * FLAME DELHI
# * WHEEZER DELL (DELL is a first name)
# * ODRISAMER DESPAIGNE
# * ORESTES DESTRADE
# * EMERSON DICKMAN (EMERSON is a last name)
# * MARTÍN DIHIGO (MARTÍN is a last name)
# * PICKLES DILLHOEFER
# * JUSTO DOMÍNGUEZ
# * OCTAVIO DOTEL
# * VALENTÍN DREKE
# * CLARO DUANY
# * SHAWON DUNSTON
# * MONTANA DURAPAU
# * ERUBIEL DURAZO
# * RAWLY EASTWICK
# * VALLIE EAVES
# * DERRIN EBERT
# * ROENIS ELIAS (ELIAS is a first name)
# * NARCISO ELVIRA
# * DIETRICH ENNS (DIETRICH is a last name)
# * ALVARO ESPINOZA
# * DUDE ESTERBROOK
# * UEL EUBANKS
# * FERD EUNICK
# * JULIÁN FABELO
# * FERRIS FAIN (FERRIS is a last name)
# * ANTON FALCH
# * JEURYS FAMILIA
# * RIKKERT FANEYTE
# * JOHNESHWY FARGAS
# * DARCY FAST (DARCY is a last name)
# * CHONE FIGGINS
# * PEMBROKE FINLAYSON
# * GAR FINNVOLD
# * ESTEVAN FLORIAL
# * BARTOLOME FORTUNATO
# * ERNESTO FRIERI
# * EMILIANO FRUTO
# * KYUJI FUJIKAWA
# * KOSUKE FUKUDOME
# * DOT FULGHUM
# * KASON GABBARD
# * YOVANI GALLARDO
# * GIOVANNY GALLEGOS
# * BALVINO GALVEZ
# * DAFF GAMMONS
# * BARBARO GARBEY
# * DEBS GARMS
# * DINTY GEARIN
# * SCOOTER GENNETT
# * GONZALEZ GERMEN (GONZALEZ is a last name)
# * PRETZELS GETZIEN
# * PEN GILLIARD
# * TINSLEY GINN (TINSLEY is a last name)
# * JERRY-DON GLEATON
# * JOT GOAR
# * LUIZ GOHARA
# * PURNAL GOLDY
# * NIKO GOODRUM
# * ASHTON GOUDEAU
# * YASMANI GRANDAL
# * KENDALL GRAVEMAN (KENDALL is a last name)
# * DIDI GREGORIUS
# * GRAYSON GREINER
# * RANDAL GRICHUK
# * DENVER GRIGSBY
# * DEIVY GRULLON
# * MAYCKOL GUAIPE
# * CECILIO GUANTE
# * CREIGHTON GUBANICH
# * REYMIN GUDUAN
# * LOURDES GURRIEL JR.
# * YULI GURRIEL
# * JANDEL GUSTAVE
# * JEDD GYORKO
# * YAMID HAAD
# * BRADIN HAGENS
# * ATLEE HAMMAKER
# * LOY HANNING
# * DEVERN HANSACK
# * TOPSY HARTSEL
# * SHIGETOSHI HASEGAWA
# * THORNY HAWKES
# * DIRK HAYHURST
# * DRUNGO HAZEWOOD
# * ADEINY HECHAVARRIA
# * CRESE HEISMANN
# * LIAM HENDRIKS
# * OLAF HENRIKSEN
# * REMY HERMOSO (REMY is a last name)
# * OREL HERSHISER
# * CODI HEUER
# * DALIER HINOJOSA
# * YOSHIHISA HIRANO
# * KESTON HIURA
# * MYRIL HOAG
# * ORIS HOCKETT
# * L.J. HOES
# * ELON HOGSETT
# * HOLLY HOLLINGSHEAD (HOLLY is a last name)
# * FROG HOLSEY
# * REGINALD HOPWOOD
# * HANSON HORSEY (HANSON is a last name)
# * WEI-CHIEH HUANG
# * MILLER HUGGINS (MILLER is a last name)
# * JAE-GYUN HWANG
# * RYOTA IGARASHI
# * KEI IGAWA
# * TADAHITO IGUCHI
# * BLAISE ILSLEY
# * ENDER INCIARTE
# * K.B. IVORY
# * HISASHI IWAKUMA
# * GENTRY JESSUP (GENTRY is a last name)
# * CHARLTON JIMERSON (CHARLTON is a last name)
# * WALDIS JOAQUIN (JOAQUIN is a first name)
# * KENJI JOHJIMA
# * SMEAD JOLLEY
# * ADDIE JOSS
# * JAKOB JUNIS
# * JAIR JURRJENS
# * KILA KA'AIHUE
# * JUNG-HO KANG
# * BENN KARR (BENN is a last name)
# * KENSHIN KAWAKAMI
# * MUNENORI KAWASAKI
# * W.L. KEANE
# * CACTUS KECK
# * KATSY KEIFER
# * KEONE KELA
# * MASAO KIDA
# * YUSEI KIKUCHI
# * HARMON KILLEBREW (HARMON is a last name)
# * ISIAH KINER-FALEFA
# * HUGO KLAERNER
# * NUB KLEINKE
# * REISS KNEHR (REISS is a last name)
# * PUNCH KNOLL
# * MASAHIDE KOBAYASHI
# * BRODY KOERNER
# * SATORU KOMIYAMA
# * DAE-SUNG KOO
# * HUNG-CHIH KUO
# * HIROKI KURODA
# * JUL KUSTUS
# * MASUMI KUWATA
# * FLIP LAFFERTY
# * LERRIN LAGROW
# * NÉSTOR LAMBERTUS
# * DINELSON LAMET
# * HOBIE LANDRITH
# * AGAPITO LÁZAGA
# * RAUDEL LAZO
# * BEVO LEBOURVEAU
# * REGIS LEHENY
# * CHANG-YONG LIM
# * VIVE LINDAMAN
# * EM LINDBECK
# * CHIA-JEN LO
# * KAMERON LOE
# * GRIFF LOMAX
# * BERNELL LONGEST
# * JESÚS LORENZO (LORENZO is a first name)
# * TOREY LOVULLO
# * FLETCHER LOW (FLETCHER is a last name)
# * DONNY LUCY
# * DOLF LUQUE
# * VIMAEL MACHIN
# * BIZ MACKEY (MACKEY is a first name)
# * WADDY MACPHEE (WADDY is a last name)
# * KENTA MAEDA
# * EVER MAGALLANES
# * DAMIEN MAGNIFICO
# * MIKIE MAHTOOK
# * DUSTER MAILS
# * VINCENT MANEY (VINCENT is a last name)
# * ALEK MANOAH
# * GEORGES MARANDA
# * FIRPO MARBERRY
# * TUCUPITA MARCANO
# * SUGAR-RAY MARIMON
# * JHAN MARINEZ
# * LEONYS MARTÍN (MARTÍN is a first name)
# * SHAIRON MARTIS
# * ONAN MASAOKA
# * GARCIA MASSINGALE (GARCIA is a last name)
# * DAISUKE MATSUZAKA
# * DAL MAXVILL
# * YUNESKY MAYA
# * TULLIE MCADOO
# * QUINTON MCCRACKEN (QUINTON is a last name)
# * TERRIS MCDUFFIE
# * STONEY MCGLYNN
# * STOVER MCILWAIN
# * TRISTON MCKENZIE
# * GREADY MCKINNIS
# * BID MCPHEE
# * MOX MCQUERY
# * TRICK MCSORLEY
# * JOUETT MEEKIN
# * KEURY MELLA
# * SCAT METHA
# * HENSLEY MEULENS (HENSLEY is a last name)
# * LEVI MEYERLE
# * KAM MICKOLIO
# * LASTINGS MILLEDGE
# * PURNELL MINCY (PURNELL is a last name)
# * VINEGAR-BEND MIZELL
# * DUSTAN MOHR
# * FENTON MOLE
# * REYES MORONTA (REYES is a last name)
# * C.D. MOSLEY
# * BITSY MOTT
# * MASANORI MURAKAMI
# * TORU MURATA
# * SIMMY MURCH
# * CHOLLY NARANJO
# * KRISTOPHER NEGRON
# * BOTS NEKOLA
# * DOVYDAS NEVERAUSKAS
# * GIFT NGOEPE
# * FU-TE NI
# * OTHO NITCHOLAS
# * HIDEO NOMO
# * TAKAHITO NOMURA
# * BUFORD NUNLEY (BUFORD is a last name)
# * REBEL OAKES (REBEL is a last name)
# * ROUGNED ODOR
# * ROWLAND OFFICE (ROWLAND is a last name)
# * SEUNGHWAN OH
# * TOMO OHKA
# * SHOHEI OHTANI
# * MAGGLIO ORDONEZ
# * PAULO ORLANDO (ORLANDO is a first name)
# * FRANQUELIS OSORIA
# * ALCIBÍADES PALMA
# * POL PERRITT
# * PRETZEL PEZZULLO
# * SQUIZ PILLION
# * STOLMY PIMENTEL
# * VADA PINSON
# * DIAMOND PIPKINS (DIAMOND is a last name)
# * TOGIE PITTINGER
# * ELMO PLASKETT
# * TOT PRESSNELL
# * JURICKSON PROFAR
# * MIGEL PUENTE
# * O'NEAL PULLEN (O'NEAL is a last name)
# * PID PURDY
# * JUNIEL QUERECUTO
# * TOMÁS QUIÑONES (TOMÁS is a last name)
# * MERRITT RANEW (MERRITT is a last name)
# * RIBS RANEY
# * RANGEL RAVELO (RAVELO is a first name)
# * RAUDY READ
# * JAKSON REETZ
# * ERWIN RENFER (ERWIN is a last name)
# * FLINT RHEM (FLINT is a last name)
# * DORSEY RIDDLEMOSER (DORSEY is a last name)
# * NIKCO RIESGO
# * JERROD RIGGAN
# * CULLEY RIKARD
# * MATÍAS RÍOS
# * EPPA RIXEY
# * SENDY RLEAL
# * BILLY-JO ROBIDOUX
# * HENRI RONDEAU
# * ROSIE ROSEBRAUGH
# * EDD ROUSH
# * JIMSEY ROUSSELL
# * BAMA ROWELL
# * MUDDY RUEL
# * GLENDON RUSCH (GLENDON is a last name)
# * CC SABATHIA
# * LENN SAKATA
# * AMAURI SANIT
# * ANASTASIO SANTAELLA
# * F.P. SANTANGELO
# * KAZUHIRO SASAKI
# * WARWICK SAUPOLD (WARWICK is a last name)
# * HIROKAZU SAWAMURA
# * CRAZY SCHMIT
# * OSSEE SCHRECONGOST
# * PI SCHWERT
# * EPP SELL
# * CAREY SELPH (CAREY is a last name)
# * JAE-WEONG SEO
# * LEYSON SEPTIMO
# * MERLE SETTLEMIRE
# * ZAK SHINALL (ZAK is a last name)
# * URBAN SHOCKER (URBAN is a last name)
# * COSTEN SHOCKLEY
# * STRICK SHOFNER (STRICK is a last name)
# * JB SHUCK
# * SIBBY SISTI
# * ROE SKIDMORE (ROE is a last name)
# * TARIK SKUBAL
# * TERRMEL SLEDGE
# * HEATHCLIFF SLOCUMB
# * CLANCY SMYRES (CLANCY is a last name)
# * COLONEL SNOVER
# * YANGERVIS SOLARTE
# * LAYNE SOMSEN (LAYNE is a last name)
# * JOAKIM SORIA
# * DENARD SPAN
# * TRIS SPEAKER
# * BY SPEECE
# * LEVALE SPEIGNER
# * SCIPIO SPINKS
# * LOCKE ST. JOHN (LOCKE is a last name)
# * HULON STAMPS
# * JIGGER STATZ
# * KENNIE STEENSTRA
# * RENNIE STENNETT
# * DERNELL STENSON
# * ROYLE STILLMAN
# * GAT STIRES
# * SNUFFY STIRNWEISS
# * LIN STORTI (LIN is a last name)
# * CUB STRICKER
# * TANYON STURTZE
# * PARK SWARTZEL (PARK is a last name)
# * OAD SWIGART
# * DOUGLAS SYDNOR (DOUGLAS is a last name)
# * KAZUHITO TADANO
# * SO TAGUCHI
# * JAMESON TAILLON
# * SHINGO TAKATSU
# * JAMUEL TARRANT
# * LA-SCHELLE TARVER
# * YOSHINORI TATEYAMA
# * JUNICHI TAZAWA
# * RECURVON TERÁN
# * KANEKOA TEXEIRA
# * JESEN THERRIEN
# * JUG THESENGA
# * VERLE TIEFENTHALER
# * LEDELL TITCOMB
# * ASHUR TOLLIVER
# * KA'AI TOM (TOM is a first name)
# * YASMANY TOMÁS (TOMÁS is a first name)
# * KELBY TOMLINSON
# * RUPE TOPPIN (RUPE is a last name)
# * CRISTÓBAL TORRIENTE
# * TOUKI TOUSSAINT (TOUSSAINT is a first name)
# * PIE TRAYNOR (PIE is a last name)
# * OVERTON TREMPER (OVERTON is a last name)
# * COAKER TRIPLETT
# * CHADWICK TROMP (CHADWICK is a last name)
# * CHIN-HUI TSAO
# * JEN-HO TSENG
# * YOSHI TSUTSUGO
# * TWINK TWINING
# * RUBY TYREES
# * KOJI UEHARA
# * UGUETH URBINA
# * JORDANY VALDESPIN
# * ELAM VANGILDER (ELAM is a last name)
# * DAYÁN VICIEDO
# * THYAGO VIEIRA
# * ENGELB VIELMA
# * MEIBRYS VILORIA
# * EDINSON VOLQUEZ
# * EWING WADDY (EWING is a last name) (WADDY is a first name)
# * LAMONTE WADE JR
# * BUZZY WARES
# * LINK WASEM (LINK is a last name)
# * EHREN WASSERMANN
# * BIGGS WEHDE (BIGGS is a last name)
# * STUMP WEIDMAN (STUMP is a last name)
# * PODGE WEIHE
# * HUYLER WESTERVELT
# * GUERDON WHITELEY
# * POSSUM WHITTED
# * ROWAN WICK (ROWAN is a last name)
# * DENNEY WILIE (DENNEY is a last name)
# * KETTLE WIRTS
# * MELLIE WOLFGANG
# * FAVEL WORDSWORTH
# * YATS WUESTLING
# * LEOVIGILDO XIQUÉS
# * KEIICHI YABU
# * YASUHIKO YABUTA
# * SHUN YAMAGUCHI
# * HYEON-JONG YANG
# * GEECH YARBOROUGH
# * YAM YARYAN
# * MASATO YOSHII
# * SEBY ZAVALA
#   399 strict members: [('JO', 'ADELL'), ('EHIRE', 'ADRIANZA'), ('SHOGO', 'AKIYAMA'), ('PORFI', 'ALTAMIRANO'), ('ADBERT', 'ALZOLAY'), ('NORI', 'AOKI'), ('SHERTEN', 'APOSTEL'), ('RUGGER', 'ARDIZOIA'), ('KOHEI', 'ARIHARA'), ('RENÉ', 'AROCHA'), ('ERISBEL', 'ARRUEBARRENA'), ('JOAQUÍN', 'ARUMÍS'), ('WILLIANS', 'ASTUDILLO'), ('ELDEN', 'AUKER'), ('SHOOTY', 'BABITT'), ('AKIL', 'BADDOO'), ('CHA-SEUNG', 'BAEK'), ('JERSEY', 'BAKLEY'), ('WLADIMIR', 'BALENTIEN'), ('STUDS', 'BANCKER'), ('JETT', 'BANDY'), ('CUNO', 'BARRAGAN'), ('KIMERA', 'BARTEE'), ('LUIS-ALEXANDER', 'BASABE'), ('BURLEY', 'BAYER'), ('DARIUS', 'BEA'), ('JALEN', 'BEEKS'), ('PETIE', 'BEHAN'), ('RENO', 'BERTOIA'), ('DELLIN', 'BETANCES'), ('RANDOR', 'BIERD'), ('RIVINGTON', 'BISLAND'), ('RAE', 'BLAEMIRE'), ('LINC', 'BLAKELY'), ('JABARI', 'BLASH'), ('XANDER', 'BOGAERTS'), ('SKYE', 'BOLT'), ('JUNG', 'BONG'), ('BOOF', 'BONSER'), ('GIBBY', 'BRACK'), ('YHENCY', 'BRAZOBAN'), ('FATTY', 'BRIODY'), ('JAYCOB', 'BRUGMAN'), ('ARLO', 'BRUNSBERG'), ('T.R.', 'BRYDEN'), ('FRANCISLEY', 'BUENO'), ('SIM', 'BULLAS'), ('JEROMY', 'BURNITZ'), ('SUBBY', 'BYAS'), ('PUTSY', 'CABALLERO'), ('ARQUIMEDES', 'CAMINERO'), ('CARDELL', 'CAMPER'), ('JEIMER', 'CANDELARIO'), ('ESMAILIN', 'CARIDAD'), ('GILBERTO', 'CELESTINO'), ('YOENIS', 'CÉSPEDES'), ('PELAYO', 'CHACÓN'), ('ITALO', 'CHELINI'), ('JAZZ', 'CHISHOLM'), ('JIN-HO', 'CHO'), ('ARCHI', 'CIANFROCCO'), ('UKE', 'CLANTON'), ('HARLOND', 'CLIFT'), ('FLEA', 'CLIFTON'), ('JD', 'CLOSSER'), ('IVANON', 'COFFIE'), ('TRACE', 'COQUILLETTE'), ('ENSIGN', 'COTTRELL'), ('MARLAN', 'COUGHTRY'), ('KALEB', 'COWART'), ('CALLIX', 'CRABBE'), ('GAVVY', 'CRAVATH'), ('CREEPY', 'CRESPI'), ('NABIL', 'CRISMATT'), ('PRESS', 'CRUTHERS'), ('EGGIE', 'DALLARD'), ('LUNIE', 'DANAGE'), ('YONATHAN', 'DAZA'), ('YURENDELL', 'DE CASTER'), ('LIONEL', 'DECUIR'), ('FLAME', 'DELHI'), ('ODRISAMER', 'DESPAIGNE'), ('ORESTES', 'DESTRADE'), ('PICKLES', 'DILLHOEFER'), ('JUSTO', 'DOMÍNGUEZ'), ('OCTAVIO', 'DOTEL'), ('VALENTÍN', 'DREKE'), ('CLARO', 'DUANY'), ('SHAWON', 'DUNSTON'), ('MONTANA', 'DURAPAU'), ('ERUBIEL', 'DURAZO'), ('RAWLY', 'EASTWICK'), ('VALLIE', 'EAVES'), ('DERRIN', 'EBERT'), ('NARCISO', 'ELVIRA'), ('ALVARO', 'ESPINOZA'), ('DUDE', 'ESTERBROOK'), ('UEL', 'EUBANKS'), ('FERD', 'EUNICK'), ('JULIÁN', 'FABELO'), ('ANTON', 'FALCH'), ('JEURYS', 'FAMILIA'), ('RIKKERT', 'FANEYTE'), ('JOHNESHWY', 'FARGAS'), ('CHONE', 'FIGGINS'), ('PEMBROKE', 'FINLAYSON'), ('GAR', 'FINNVOLD'), ('ESTEVAN', 'FLORIAL'), ('BARTOLOME', 'FORTUNATO'), ('ERNESTO', 'FRIERI'), ('EMILIANO', 'FRUTO'), ('KYUJI', 'FUJIKAWA'), ('KOSUKE', 'FUKUDOME'), ('DOT', 'FULGHUM'), ('KASON', 'GABBARD'), ('YOVANI', 'GALLARDO'), ('GIOVANNY', 'GALLEGOS'), ('BALVINO', 'GALVEZ'), ('DAFF', 'GAMMONS'), ('BARBARO', 'GARBEY'), ('DEBS', 'GARMS'), ('DINTY', 'GEARIN'), ('SCOOTER', 'GENNETT'), ('PRETZELS', 'GETZIEN'), ('PEN', 'GILLIARD'), ('JERRY-DON', 'GLEATON'), ('JOT', 'GOAR'), ('LUIZ', 'GOHARA'), ('PURNAL', 'GOLDY'), ('NIKO', 'GOODRUM'), ('ASHTON', 'GOUDEAU'), ('YASMANI', 'GRANDAL'), ('DIDI', 'GREGORIUS'), ('GRAYSON', 'GREINER'), ('RANDAL', 'GRICHUK'), ('DENVER', 'GRIGSBY'), ('DEIVY', 'GRULLON'), ('MAYCKOL', 'GUAIPE'), ('CECILIO', 'GUANTE'), ('CREIGHTON', 'GUBANICH'), ('REYMIN', 'GUDUAN'), ('LOURDES', 'GURRIEL JR.'), ('YULI', 'GURRIEL'), ('JANDEL', 'GUSTAVE'), ('JEDD', 'GYORKO'), ('YAMID', 'HAAD'), ('BRADIN', 'HAGENS'), ('ATLEE', 'HAMMAKER'), ('LOY', 'HANNING'), ('DEVERN', 'HANSACK'), ('TOPSY', 'HARTSEL'), ('SHIGETOSHI', 'HASEGAWA'), ('THORNY', 'HAWKES'), ('DIRK', 'HAYHURST'), ('DRUNGO', 'HAZEWOOD'), ('ADEINY', 'HECHAVARRIA'), ('CRESE', 'HEISMANN'), ('LIAM', 'HENDRIKS'), ('OLAF', 'HENRIKSEN'), ('OREL', 'HERSHISER'), ('CODI', 'HEUER'), ('DALIER', 'HINOJOSA'), ('YOSHIHISA', 'HIRANO'), ('KESTON', 'HIURA'), ('MYRIL', 'HOAG'), ('ORIS', 'HOCKETT'), ('L.J.', 'HOES'), ('ELON', 'HOGSETT'), ('FROG', 'HOLSEY'), ('REGINALD', 'HOPWOOD'), ('WEI-CHIEH', 'HUANG'), ('JAE-GYUN', 'HWANG'), ('RYOTA', 'IGARASHI'), ('KEI', 'IGAWA'), ('TADAHITO', 'IGUCHI'), ('BLAISE', 'ILSLEY'), ('ENDER', ...
#    96 non-strict members: {('CLANCY', 'SMYRES'), ('BURKE', 'BADENHOP'), ('PIE', 'TRAYNOR'), ('ERWIN', 'RENFER'), ('CHADWICK', 'TROMP'), ('HENSLEY', 'MEULENS'), ('REBEL', 'OAKES'), ('RANGEL', 'RAVELO'), ('BIZ', 'MACKEY'), ('DENNEY', 'WILIE'), ('TOMÁS', 'QUIÑONES'), ('MILLER', 'HUGGINS'), ('EMERSON', 'DICKMAN'), ('REMY', 'HERMOSO'), ('RUPE', 'TOPPIN'), ('OVERTON', 'TREMPER'), ('KENDALL', 'GRAVEMAN'), ('HENDERSON', 'ALVAREZ III'), ('PHILLIPPE', 'AUMONT'), ('GALEN', 'CISCO'), ('CONRAD', 'CARDINAL'), ('TEJAY', 'ANTONE'), ('GIBSON', 'ALBA'), ('RALEIGH', 'AITCHISON'), ('SKINNER', 'BELFIELD'), ('CHARLTON', 'JIMERSON'), ('URBAN', 'SHOCKER'), ('FERRIS', 'FAIN'), ('ABIATAL', 'AVELINO'), ('QUINTON', 'MCCRACKEN'), ('DOE', 'BOYLAND'), ('DARCY', 'FAST'), ('STUMP', 'WEIDMAN'), ("O'NEAL", 'PULLEN'), ('STRICK', 'SHOFNER'), ('REISS', 'KNEHR'), ('LINK', 'WASEM'), ('WADDY', 'MACPHEE'), ('TINSLEY', 'GINN'), ('HARMON', 'KILLEBREW'), ('LAYNE', 'SOMSEN'), ('PURNELL', 'MINCY'), ('FLETCHER', 'LOW'), ('PAULO', 'ORLANDO'), ('CAREY', 'SELPH'), ('DORSEY', 'RIDDLEMOSER'), ('SALOME', 'BAROJAS'), ('BARRETT', 'ASTIN'), ('GLENDON', 'RUSCH'), ('WALTON', 'CRUISE'), ('GOWELL', 'CLASET'), ('WARWICK', 'SAUPOLD'), ('LOCKE', 'ST. JOHN'), ('ROWLAND', 'OFFICE'), ('HANSER', 'ALBERTO'), ('DIETRICH', 'ENNS'), ('ROE', 'SKIDMORE'), ('ROENIS', 'ELIAS'), ('PARK', 'SWARTZEL'), ('ZAK', 'SHINALL'), ('EWING', 'WADDY'), ('GARTON', 'DEL SAVIO'), ('YASMANY', 'TOMÁS'), ('LIN', 'STORTI'), ('MARTÍN', 'DIHIGO'), ('JHAREL', 'COTTON'), ('RAINEY', 'BIBBS'), ('BUFORD', 'NUNLEY'), ('FLINT', 'RHEM'), ('SHIN-SOO', 'CHOO'), ('ROWAN', 'WICK'), ('ROCCO', 'BALDELLI'), ('ELAM', 'VANGILDER'), ('GONZALEZ', 'GERMEN'), ('HOLLY', 'HOLLINGSHEAD'), ('ÁNGEL', 'ALFONSO'), ('GAIR', 'ALLIE'), ('GENTRY', 'JESSUP'), ('VINCENT', 'MANEY'), ('MERRITT', 'RANEW'), ('CISCO', 'CARLOS'), ('WHEEZER', 'DELL'), ('LEONYS', 'MARTÍN'), ('DOUGLAS', 'SYDNOR'), ('BENN', 'KARR'), ('KEEFE', 'CATO'), ('JESÚS', 'LORENZO'), ('BIGGS', 'WEHDE'), ('GARCIA', 'MASSINGALE'), ('HANSON', 'HORSEY'), ('REYES', 'MORONTA'), ('PELHAM', 'BALLENGER'), ("KA'AI", 'TOM'), ('TOUKI', 'TOUSSAINT'), ('WALDIS', 'JOAQUIN'), ('DIAMOND', 'PIPKINS')}
